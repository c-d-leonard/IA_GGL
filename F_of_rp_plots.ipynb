# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
F_a = np.loadtxt('./txtfiles/photo_z_test/F_a_DESY1_no_fidIA_assumedpar_OmM=0.3_HH0=72.0.txt', unpack=True)
F_b = np.loadtxt('./txtfiles/photo_z_test/F_b_DESY1_no_fidIA_assumedpar_OmM=0.3_HH0=72.0.txt', unpack=True)

# %%
theta , gamma = np.loadtxt('./txtfiles/photo_z_test/gamma_IA_est_DESY1_no_fidIA_assumedpar_OmM=0.3_HH0=72.0.txt', unpack=True)

# %%
plt.figure()
plt.semilogx(theta,F_a, 'o')
plt.ylabel('F, low z sources')
plt.xlabel('$\\theta$, arcmin')
#plt.show()
plt.savefig('./F_lowz.pdf')

# %%
plt.figure()
plt.semilogx(theta,F_b, 'o')
plt.ylabel('F, high z sources')
plt.xlabel('$\\theta$, arcmin')
#plt.show()
plt.savefig('./F_highz.pdf')
