# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
survey = 'SDSS'

(rp, StoN_Blazek) = np.loadtxt('./txtfiles/StoN/StoN_sysb_stat_Blazek_'+survey+'_deltaz=0.17_rlim=22.0.txt', unpack=True)
(rp, StoN_shapes_1) = np.loadtxt('./txtfiles/StoN/StoN_sysB_stat_shapes_'+survey+'_rlim=22.0_a0pt2_rho0pt8.txt', unpack=True)
(rp, StoN_shapes_2) = np.loadtxt('./txtfiles/StoN/StoN_sysB_stat_shapes_'+survey+'_rlim=22.0_a0pt8_rho0pt2.txt', unpack=True)

# %%
plt.rc('font', family='serif', size=14)
f, axarr = plt.subplots(2, sharex=True, figsize=[5,8])
axarr[0].scatter(rp, StoN_shapes_1, color='b', marker='^', s=100, label='$a=0.2, \, \\rho=0.8$')
axarr[0].hold(True)
axarr[0].scatter(rp ,StoN_shapes_2,color='#FFA500', marker='o', s=100, label='$a=0.8, \, \\rho=0.2$')
axarr[1].scatter(rp , StoN_shapes_1 / StoN_Blazek, color='b', marker='^', s=100, label='$a=0.2, \, \\rho=0.8$')
axarr[1].hold(True)
axarr[1].scatter(rp ,StoN_shapes_2 / StoN_Blazek,color='#FFA500', marker='o', s=100, label='$a=0.8, \, \\rho=0.2$')
axarr[0].set_xscale("log")
axarr[1].set_ylim(0, 2.5)
axarr[0].set_ylim(0, 1.5)
axarr[0].set_xlim(0.05,20.)
axarr[1].set_xlabel('$r_p, \, {\\rm Mpc / h}$', fontsize=20)
axarr[0].set_ylabel('$S/N$', fontsize=20)
axarr[1].set_ylabel('$\\frac{S/N}{S/N_{\\rm B2012}}$', fontsize=30)
axarr[0].legend(loc='upper left', fontsize=14)
plt.tight_layout()
plt.savefig('./plots/StoN1d_SDSS_2vs8_fixcz.png')
#plt.show()

"""fig_sub=plt.subplot(111)
plt.rc('font', family='serif', size=14)
fig_sub.scatter(rp , StoN_shapes_1 / StoN_Blazek, color='b', marker='^', s=100, label='$a=0.2, \, \\rho=0.8$')
fig_sub.hold(True)
fig_sub.scatter(rp ,StoN_shapes_2 / StoN_Blazek,color='#FFA500', marker='o', s=100, label='$a=0.8, \, \\rho=0.2$')
fig_sub.set_xscale("log")
fig_sub.set_xlabel('$r_p, \, {\\rm Mpc / h}$', fontsize=30)
fig_sub.set_ylabel('$\\frac{S/N}{S/N_{\\rm B2012}}$', fontsize=30)
fig_sub.set_ylim(0, 5)
fig_sub.set_xlim(0.05,20.)
fig_sub.tick_params(axis='both', which='major', labelsize=18)
fig_sub.tick_params(axis='both', which='minor', labelsize=18)
fig_sub.legend(loc='upper left')
#plt.title('SDSS sources + SDSS lenses. $a, \, \\rho=0.8$')
plt.tight_layout()
plt.savefig('./plots/StoN1d_SDSS_ratio_2vs8_rlim=22.png')
#plt.show()"""
# Out:
# 'fig_sub=plt.subplot(111)\nplt.rc(\'font\', family=\'serif\', size=14)\nfig_sub.scatter(rp , StoN_shapes_1 / StoN_Blazek, color=\'b\', marker=\'^\', s=100, label=\'$a=0.2, \\, \\rho=0.8$\')\nfig_sub.hold(True)\nfig_sub.scatter(rp ,StoN_shapes_2 / StoN_Blazek,color=\'#FFA500\', marker=\'o\', s=100, label=\'$a=0.8, \\, \\rho=0.2$\')\nfig_sub.set_xscale("log")\nfig_sub.set_xlabel(\'$r_p, \\, {\\rm Mpc / h}$\', fontsize=30)\nfig_sub.set_ylabel(\'$\\frac{S/N}{S/N_{\\rm B2012}}$\', fontsize=30)\nfig_sub.set_ylim(0, 5)\nfig_sub.set_xlim(0.05,20.)\nfig_sub.tick_params(axis=\'both\', which=\'major\', labelsize=18)\nfig_sub.tick_params(axis=\'both\', which=\'minor\', labelsize=18)\nfig_sub.legend(loc=\'upper left\')\n#plt.title(\'SDSS sources + SDSS lenses. $a, \\, \\rho=0.8$\')\nplt.tight_layout()\nplt.savefig(\'./plots/StoN1d_SDSS_ratio_2vs8_rlim=22.png\')\n#plt.show()'

# %%
survey = 'LSST_DESI'

rlim = 25.3

(rp, StoN_Blazek) = np.loadtxt('./txtfiles/StoN/StoN_sysb_stat_Blazek_'+survey+'_deltaz=0.1_rlim=25.3.txt', unpack=True)
(rp, StoN_shapes_1) = np.loadtxt('./txtfiles/StoN/StoN_sysB_stat_shapes_'+survey+'_rlim=25.3_a0pt2_rho0pt8.txt', unpack=True)
(rp, StoN_shapes_2) = np.loadtxt('./txtfiles/StoN/StoN_sysB_stat_shapes_'+survey+'_rlim=25.3_a0pt8_rho0pt2.txt', unpack=True)

# %%
print "StoN_Blazek=", StoN_Blazek
plt.rc('font', family='serif', size=14)
f, axarr = plt.subplots(2, sharex=True, figsize=[5,8])
axarr[0].scatter(rp, StoN_shapes_1, color='b', marker='^', s=100, label='$a=0.2, \, \\rho=0.8$')
axarr[0].hold(True)
axarr[0].scatter(rp ,StoN_shapes_2,color='#FFA500', marker='o', s=100, label='$a=0.8, \, \\rho=0.2$')
axarr[1].scatter(rp , StoN_shapes_1 / StoN_Blazek, color='b', marker='^', s=100, label='$a=0.2, \, \\rho=0.8$')
axarr[1].hold(True)
axarr[1].scatter(rp ,StoN_shapes_2 / StoN_Blazek,color='#FFA500', marker='o', s=100, label='$a=0.8, \, \\rho=0.2$')
axarr[0].set_xscale("log")
axarr[1].set_ylim(0, 2.5)
axarr[0].set_ylim(0, 12)
axarr[0].set_xlim(0.05,20.)
axarr[1].set_xlabel('$r_p, \, {\\rm Mpc / h}$', fontsize=20)
axarr[0].set_ylabel('$S/N$', fontsize=20)
axarr[1].set_ylabel('$\\frac{S/N}{S/N_{\\rm B2012}}$', fontsize=30)
axarr[0].legend(loc='upper left', fontsize=14)
plt.tight_layout()
plt.savefig('./plots/StoN1d_LSST_2vs8_fixcz.png')
plt.show()

"""fig_sub=plt.subplot(111)
plt.rc('font', family='serif', size=14)
fig_sub.scatter(rp , StoN_shapes_1 / StoN_Blazek, color='b', marker='^', s=100, label='$a=0.2, \, \\rho=0.8$')
fig_sub.hold(True)
fig_sub.scatter(rp ,StoN_shapes_2 / StoN_Blazek,color='#FFA500', marker='o', s=100, label='$a=0.8, \, \\rho=0.2$')
fig_sub.set_xscale("log")
fig_sub.set_xlabel('$r_p, \, {\\rm Mpc / h}$', fontsize=30)
fig_sub.set_ylabel('$\\frac{S/N}{S/N_{\\rm B2012}}$', fontsize=30)
fig_sub.set_ylim(0, 5.)
fig_sub.set_xlim(0.05,20.)
fig_sub.tick_params(axis='both', which='major', labelsize=18)
fig_sub.tick_params(axis='both', which='minor', labelsize=18)
fig_sub.legend(loc='upper left')
plt.tight_layout()
#plt.title('SDSS sources + SDSS lenses. $a, \, \\rho=0.8$')
plt.savefig('./plots/StoN1d_LSST_ratio_rlim=25.3_2vs8.png')
plt.show()"""
# Out:
# StoN_Blazek= [ 0.20031159  0.54233567  1.48838069  3.90251832  4.45495234  2.7142674
#   2.70588818]
# 'fig_sub=plt.subplot(111)\nplt.rc(\'font\', family=\'serif\', size=14)\nfig_sub.scatter(rp , StoN_shapes_1 / StoN_Blazek, color=\'b\', marker=\'^\', s=100, label=\'$a=0.2, \\, \\rho=0.8$\')\nfig_sub.hold(True)\nfig_sub.scatter(rp ,StoN_shapes_2 / StoN_Blazek,color=\'#FFA500\', marker=\'o\', s=100, label=\'$a=0.8, \\, \\rho=0.2$\')\nfig_sub.set_xscale("log")\nfig_sub.set_xlabel(\'$r_p, \\, {\\rm Mpc / h}$\', fontsize=30)\nfig_sub.set_ylabel(\'$\\frac{S/N}{S/N_{\\rm B2012}}$\', fontsize=30)\nfig_sub.set_ylim(0, 5.)\nfig_sub.set_xlim(0.05,20.)\nfig_sub.tick_params(axis=\'both\', which=\'major\', labelsize=18)\nfig_sub.tick_params(axis=\'both\', which=\'minor\', labelsize=18)\nfig_sub.legend(loc=\'upper left\')\nplt.tight_layout()\n#plt.title(\'SDSS sources + SDSS lenses. $a, \\, \\rho=0.8$\')\nplt.savefig(\'./plots/StoN1d_LSST_ratio_rlim=25.3_2vs8.png\')\nplt.show()'
