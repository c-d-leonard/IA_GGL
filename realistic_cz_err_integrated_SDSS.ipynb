# %% [markdown]
# We want to know what is the acceptable level of error on c_z for SDSS and LSST_DESI such that statistical error dominates the error budget.

# %%
# %matplotlib inline
import numpy as np; import constrain_IA_BlazekMethod as Bl
import shared_functions_setup as setup
import matplotlib.pyplot as plt
# Out:
# SURVEY= LSST_DESI
# /usr/local/lib/python2.7/dist-packages/halotools/sim_manager/halo_table_cache.py:12: UserWarning: Some of the functionality of the HaloTableCache classrequires h5py to be installed.
#   warn("Some of the functionality of the HaloTableCache class"
# /usr/local/lib/python2.7/dist-packages/halotools/sim_manager/user_supplied_ptcl_catalog.py:13: UserWarning: Most of the functionality of the sim_manager sub-package requires h5py to be installed,
# which can be accomplished either with pip or conda
#   warn("Most of the functionality of the sim_manager "
# /usr/local/lib/python2.7/dist-packages/halotools/sim_manager/download_manager.py:39: UserWarning: Some of the functionality of the DownloadManager requires h5py to be installed,
# which can be accomplished either with pip or conda
#   warn("Some of the functionality of the DownloadManager requires h5py to be installed,\n"
# /usr/local/lib/python2.7/dist-packages/halotools/sim_manager/cached_halo_catalog.py:15: UserWarning: Most of the functionality of the sim_manager sub-package requires h5py to be installed,
# which can be accomplished either with pip or conda.
#   warn("Most of the functionality of the "
# Loading wgg 1halo term from file.
# Loading wgg 2halo term from file.
# Loading wgp 1halo term from file
# Loading wgp 2halo term from file
# F values have already been computed for this endfile.
# SigIA values have already been computed for this endfile.
# Sig_ex_a_fid= [ 8715.60256888  8715.60256888  8715.60256888  8715.60256888  8715.60256888  8715.60256888  8715.60256888]
# Sig_ex_b_fid= [ 3870.14897719  3870.14897719  3870.14897719  3870.14897719  3870.14897719  3870.14897719  3870.14897719]
# cz values have already been computed for this endfile.
# Running, systematic level #1
# Running, systematic level #2
# Running, systematic level #3
# Running, systematic level #4
# Running, systematic level #5
# Running, systematic level #6
# Running, systematic level #7
# Running, systematic level #8
# Running, systematic level #9
# Running, systematic level #10
# Running, systematic level #11
# Running, systematic level #12
# Running, systematic level #13
# Running, systematic level #14
# Running, systematic level #15
# Running, systematic level #16
# Running, systematic level #17
# Running, systematic level #18
# Running, systematic level #19
# Running, systematic level #20
# Running, systematic level #21
# Running, systematic level #22
# Running, systematic level #23
# Running, systematic level #24
# Running, systematic level #25
# Running, systematic level #26
# Running, systematic level #27
# Running, systematic level #28
# Running, systematic level #29
# Running, systematic level #30
# Running, systematic level #31
# Running, systematic level #32
# Running, systematic level #33
# Running, systematic level #34
# Running, systematic level #35
# Running, systematic level #36
# Running, systematic level #37
# Running, systematic level #38
# Running, systematic level #39
# Running, systematic level #40
# Running, systematic level #41
# Running, systematic level #42
# Running, systematic level #43
# Running, systematic level #44
# Running, systematic level #45
# Running, systematic level #46
# Running, systematic level #47
# Running, systematic level #48
# Running, systematic level #49
# Running, systematic level #50
# Running, systematic level #51
# Running, systematic level #52
# Running, systematic level #53
# Running, systematic level #54
# Running, systematic level #55
# Running, systematic level #56
# Running, systematic level #57
# Running, systematic level #58
# Running, systematic level #59
# Running, systematic level #60
# Running, systematic level #61
# Running, systematic level #62
# Running, systematic level #63
# Running, systematic level #64
# Running, systematic level #65
# Running, systematic level #66
# Running, systematic level #67
# Running, systematic level #68
# Running, systematic level #69
# Running, systematic level #70
# Running, systematic level #71
# Running, systematic level #72
# Running, systematic level #73
# Running, systematic level #74
# Running, systematic level #75
# Running, systematic level #76
# Running, systematic level #77
# Running, systematic level #78
# Running, systematic level #79
# Running, systematic level #80
# Running, systematic level #81
# Running, systematic level #82
# Running, systematic level #83
# Running, systematic level #84
# Running, systematic level #85
# Running, systematic level #86
# Running, systematic level #87
# Running, systematic level #88
# Running, systematic level #89
# Running, systematic level #90
# Running, systematic level #91
# Running, systematic level #92
# Running, systematic level #93
# Running, systematic level #94
# Running, systematic level #95
# Running, systematic level #96
# Running, systematic level #97
# Running, systematic level #98
# Running, systematic level #99
# Running, systematic level #100
# Running, systematic level #101
# Running, systematic level #102
# Running, systematic level #103
# Running, systematic level #104
# Running, systematic level #105
# Running, systematic level #106
# Running, systematic level #107
# Running, systematic level #108
# Running, systematic level #109
# Running, systematic level #110
# Running, systematic level #111
# Running, systematic level #112
# Running, systematic level #113
# Running, systematic level #114
# Running, systematic level #115
# Running, systematic level #116
# Running, systematic level #117
# Running, systematic level #118
# Running, systematic level #119
# Running, systematic level #120
# Running, systematic level #121
# Running, systematic level #122
# Running, systematic level #123
# Running, systematic level #124
# Running, systematic level #125
# Running, systematic level #126
# Running, systematic level #127
# Running, systematic level #128
# Running, systematic level #129
# Running, systematic level #130
# Running, systematic level #131
# Running, systematic level #132
# Running, systematic level #133
# Running, systematic level #134
# Running, systematic level #135
# Running, systematic level #136
# Running, systematic level #137
# Running, systematic level #138
# Running, systematic level #139
# Running, systematic level #140
# Running, systematic level #141
# Running, systematic level #142
# Running, systematic level #143
# Running, systematic level #144
# Running, systematic level #145
# Running, systematic level #146
# Running, systematic level #147
# Running, systematic level #148
# Running, systematic level #149
# Running, systematic level #150
# Running, systematic level #151
# Running, systematic level #152
# Running, systematic level #153
# Running, systematic level #154
# Running, systematic level #155
# Running, systematic level #156
# Running, systematic level #157
# Running, systematic level #158
# Running, systematic level #159
# Running, systematic level #160
# Running, systematic level #161
# Running, systematic level #162
# Running, systematic level #163
# Running, systematic level #164
# Running, systematic level #165
# Running, systematic level #166
# Running, systematic level #167
# Running, systematic level #168
# Running, systematic level #169
# Running, systematic level #170
# Running, systematic level #171
# Running, systematic level #172
# Running, systematic level #173
# Running, systematic level #174
# Running, systematic level #175
# Running, systematic level #176
# Running, systematic level #177
# Running, systematic level #178
# Running, systematic level #179
# Running, systematic level #180
# Running, systematic level #181
# Running, systematic level #182
# Running, systematic level #183
# Running, systematic level #184
# Running, systematic level #185
# Running, systematic level #186
# Running, systematic level #187
# Running, systematic level #188
# Running, systematic level #189
# Running, systematic level #190
# Running, systematic level #191
# Running, systematic level #192
# Running, systematic level #193
# Running, systematic level #194
# Running, systematic level #195
# Running, systematic level #196
# Running, systematic level #197
# Running, systematic level #198
# Running, systematic level #199
# Running, systematic level #200
# Running, systematic level #201
# Running, systematic level #202
# Running, systematic level #203
# Running, systematic level #204
# Running, systematic level #205
# Running, systematic level #206
# Running, systematic level #207
# Running, systematic level #208
# Running, systematic level #209
# Running, systematic level #210
# Running, systematic level #211
# Running, systematic level #212
# Running, systematic level #213
# Running, systematic level #214
# Running, systematic level #215
# Running, systematic level #216
# Running, systematic level #217
# Running, systematic level #218
# Running, systematic level #219
# Running, systematic level #220
# Running, systematic level #221
# Running, systematic level #222
# Running, systematic level #223
# Running, systematic level #224
# Running, systematic level #225
# Running, systematic level #226
# Running, systematic level #227
# Running, systematic level #228
# Running, systematic level #229
# Running, systematic level #230
# Running, systematic level #231
# Running, systematic level #232
# Running, systematic level #233
# Running, systematic level #234
# Running, systematic level #235
# Running, systematic level #236
# Running, systematic level #237
# Running, systematic level #238
# Running, systematic level #239
# Running, systematic level #240
# Running, systematic level #241
# Running, systematic level #242
# Running, systematic level #243
# Running, systematic level #244
# Running, systematic level #245
# Running, systematic level #246
# Running, systematic level #247
# Running, systematic level #248
# Running, systematic level #249
# Running, systematic level #250
# Running, systematic level #251
# Running, systematic level #252
# Running, systematic level #253
# Running, systematic level #254
# Running, systematic level #255
# Running, systematic level #256
# Running, systematic level #257
# Running, systematic level #258
# Running, systematic level #259
# Running, systematic level #260
# Running, systematic level #261
# Running, systematic level #262
# Running, systematic level #263
# Running, systematic level #264
# Running, systematic level #265
# Running, systematic level #266
# Running, systematic level #267
# Running, systematic level #268
# Running, systematic level #269
# Running, systematic level #270
# Running, systematic level #271
# Running, systematic level #272
# Running, systematic level #273
# Running, systematic level #274
# Running, systematic level #275
# Running, systematic level #276
# Running, systematic level #277
# Running, systematic level #278
# Running, systematic level #279
# Running, systematic level #280
# Running, systematic level #281
# Running, systematic level #282
# Running, systematic level #283
# Running, systematic level #284
# Running, systematic level #285
# Running, systematic level #286
# Running, systematic level #287
# Running, systematic level #288
# Running, systematic level #289
# Running, systematic level #290
# Running, systematic level #291
# Running, systematic level #292
# Running, systematic level #293
# Running, systematic level #294
# Running, systematic level #295
# Running, systematic level #296
# Running, systematic level #297
# Running, systematic level #298
# Running, systematic level #299
# Running, systematic level #300
# Running, systematic level #301
# Running, systematic level #302
# Running, systematic level #303
# Running, systematic level #304
# Running, systematic level #305
# Running, systematic level #306
# Running, systematic level #307
# Running, systematic level #308
# Running, systematic level #309
# Running, systematic level #310
# Running, systematic level #311
# Running, systematic level #312
# Running, systematic level #313
# Running, systematic level #314
# Running, systematic level #315
# Running, systematic level #316
# Running, systematic level #317
# Running, systematic level #318
# Running, systematic level #319
# Running, systematic level #320
# Running, systematic level #321
# Running, systematic level #322
# Running, systematic level #323
# Running, systematic level #324
# Running, systematic level #325
# Running, systematic level #326
# Running, systematic level #327
# Running, systematic level #328
# Running, systematic level #329
# Running, systematic level #330
# Running, systematic level #331
# Running, systematic level #332
# Running, systematic level #333
# Running, systematic level #334
# Running, systematic level #335
# Running, systematic level #336
# Running, systematic level #337
# Running, systematic level #338
# Running, systematic level #339
# Running, systematic level #340
# Running, systematic level #341
# Running, systematic level #342
# Running, systematic level #343
# Running, systematic level #344
# Running, systematic level #345
# Running, systematic level #346
# Running, systematic level #347
# Running, systematic level #348
# Running, systematic level #349
# Running, systematic level #350
# Running, systematic level #351
# Running, systematic level #352
# Running, systematic level #353
# Running, systematic level #354
# Running, systematic level #355
# Running, systematic level #356
# Running, systematic level #357
# Running, systematic level #358
# Running, systematic level #359
# Running, systematic level #360
# Running, systematic level #361
# Running, systematic level #362
# Running, systematic level #363
# Running, systematic level #364
# Running, systematic level #365
# Running, systematic level #366
# Running, systematic level #367
# Running, systematic level #368
# Running, systematic level #369
# Running, systematic level #370
# Running, systematic level #371
# Running, systematic level #372
# Running, systematic level #373
# Running, systematic level #374
# Running, systematic level #375
# Running, systematic level #376
# Running, systematic level #377
# Running, systematic level #378
# Running, systematic level #379
# Running, systematic level #380
# Running, systematic level #381
# Running, systematic level #382
# Running, systematic level #383
# Running, systematic level #384
# Running, systematic level #385
# Running, systematic level #386
# Running, systematic level #387
# Running, systematic level #388
# Running, systematic level #389
# Running, systematic level #390
# Running, systematic level #391
# Running, systematic level #392
# Running, systematic level #393
# Running, systematic level #394
# Running, systematic level #395
# Running, systematic level #396
# Running, systematic level #397
# Running, systematic level #398
# Running, systematic level #399
# Running, systematic level #400
# Running, systematic level #401
# Running, systematic level #402
# Running, systematic level #403
# Running, systematic level #404
# Running, systematic level #405
# Running, systematic level #406
# Running, systematic level #407
# Running, systematic level #408
# Running, systematic level #409
# Running, systematic level #410
# Running, systematic level #411
# Running, systematic level #412
# Running, systematic level #413
# Running, systematic level #414
# Running, systematic level #415
# Running, systematic level #416
# Running, systematic level #417
# Running, systematic level #418
# Running, systematic level #419
# Running, systematic level #420
# Running, systematic level #421
# Running, systematic level #422
# Running, systematic level #423
# Running, systematic level #424
# Running, systematic level #425
# Running, systematic level #426
# Running, systematic level #427
# Running, systematic level #428
# Running, systematic level #429
# Running, systematic level #430
# Running, systematic level #431
# Running, systematic level #432
# Running, systematic level #433
# Running, systematic level #434
# Running, systematic level #435
# Running, systematic level #436
# Running, systematic level #437
# Running, systematic level #438
# Running, systematic level #439
# Running, systematic level #440
# Running, systematic level #441
# Running, systematic level #442
# Running, systematic level #443
# Running, systematic level #444
# Running, systematic level #445
# Running, systematic level #446
# Running, systematic level #447
# Running, systematic level #448
# Running, systematic level #449
# Running, systematic level #450
# Running, systematic level #451
# Running, systematic level #452
# Running, systematic level #453
# Running, systematic level #454
# Running, systematic level #455
# Running, systematic level #456
# Running, systematic level #457
# Running, systematic level #458
# Running, systematic level #459
# Running, systematic level #460
# Running, systematic level #461
# Running, systematic level #462
# Running, systematic level #463
# Running, systematic level #464
# Running, systematic level #465
# Running, systematic level #466
# Running, systematic level #467
# Running, systematic level #468
# Running, systematic level #469
# Running, systematic level #470
# Running, systematic level #471
# Running, systematic level #472
# Running, systematic level #473
# Running, systematic level #474
# Running, systematic level #475
# Running, systematic level #476
# Running, systematic level #477
# Running, systematic level #478
# Running, systematic level #479
# Running, systematic level #480
# Running, systematic level #481
# Running, systematic level #482
# Running, systematic level #483
# Running, systematic level #484
# Running, systematic level #485
# Running, systematic level #486
# Running, systematic level #487
# Running, systematic level #488
# Running, systematic level #489
# Running, systematic level #490
# Running, systematic level #491
# Running, systematic level #492
# Running, systematic level #493
# Running, systematic level #494
# Running, systematic level #495
# Running, systematic level #496
# Running, systematic level #497
# Running, systematic level #498
# Running, systematic level #499
# Running, systematic level #500

# %% [markdown]
# $\Delta \Sigma = c_z \widetilde{\Delta \Sigma}$. Therefore, ${\rm Cov}(\Delta \Sigma(r_p), \Delta \Sigma(r_p^\prime)= \frac{\sigma^2(c_z)}{c_z^2} \widetilde{\Delta\Sigma}(r_p) \widetilde{\Delta\Sigma}(r_p^\prime) $
# Let us suppose that we want the fractional integrated (over $r_p$) error on $\Delta\Sigma$ due to $c_z$ to make up no more than $x\%$ of the total integrated error.

# %%
x=0.5 # 50 percent

# %% [markdown]
# We want to know for what values of $\frac{\sigma(c_z)}{c_z}$ is it true that $\frac{N/S_{\rm sys}}{N/S_{\rm tot}}\le x$ where $N/S$ is the integrated inverse signal to noise over $r_p$ scales. Let's assume that the covariance of the 'B' source sample galaxy galaxy lensing is characteristic of a typical lensing measurement we would want to make.

# %%
#Get the statistical covariance matrix and statistical only signal to noise
SURVEY = 'LSST_DESI'
if (SURVEY=='SDSS'):
    import params as pa
elif (SURVEY=='LSST_DESI'):
    import params_LSST_DESI as pa
else:
    print "We don't have support for that survey yet; exiting."
    exit()

cov_DS_stat_SDSS = np.loadtxt('./txtfiles/covmats/cov_DelSig_zLext_LSST_DESI_sample=B_rpts2000_lpts100000_deltaz=0.1_fixDls.txt')

# %% [markdown]
# Get the theoretical $\Delta \Sigma$ from lensing only and then the estimated $\widetilde{\Delta \Sigma}$ from the fiducial values of $c_z^b$.

# %%
rp_bins  = setup.setup_rp_bins(pa.rp_min, pa.rp_max, pa.N_bins)
rp_cent  = setup.rp_bins_mid(rp_bins)
DeltaSig = Bl.get_DeltaSig_theory(rp_bins, rp_cent)
(cz_a_fid, cz_b_fid) = np.loadtxt('./txtfiles/cz/cz_afid_bfid_extl_survey=LSST_DESI_deltaz=0.1_fixDls.txt', unpack=True)
EstDeltaSig = np.asarray(DeltaSig) / cz_b_fid

# %% [markdown]
# Get the square of the statistical-only signal to noise

# %%
# Statistical only signal-to-noise
# this is WRONG it should be the THEORETICAL delta sigma covariance matrix, needs factors of c_z
# see updated version in constrain_blazek fiile
stat_StoNsq = np.dot(DeltaSig, np.dot(np.linalg.inv(cov_DS_stat_SDSS), DeltaSig))

# %% [markdown]
# Get the covariance matrix due to systematic error on cz for a variety of $\frac{\sigma(c_z)}{c_z}$ values. Combine with the statistical covariance matrix to get the total matrix, and from there get the signal to noise due to systematic error on $c_z$ and $\frac{N/S_{\rm sys}}{N/S_{\rm tot}}$ for each value of $\frac{\sigma(c_z)}{c_z}$.

# %%
frac_err_sys = np.zeros(len(pa.fudge_frac_level))
for fi in range(0, len(pa.fudge_frac_level)):
    cov_DS_sys_SDSS = np.zeros((len(rp_cent), len(rp_cent)))
    for rpi in range(0,len(rp_cent)):
        for rpj in range(0,len(rp_cent)):
            cov_DS_sys_SDSS[rpi, rpj] = pa.fudge_frac_level[fi]**2 * DeltaSig[rpi] * DeltaSig[rpj]
            
    cov_tot = cov_DS_sys_SDSS + cov_DS_stat_SDSS
    StoN_tot_sq = np.dot(DeltaSig, np.dot(np.linalg.inv(cov_tot), DeltaSig))
    NtoS_sys = np.sqrt( StoN_tot_sq**(-1) - stat_StoNsq**(-1))
    frac_err_sys[fi] = NtoS_sys / (np.sqrt(StoN_tot_sq)**(-1))

# %% [markdown]
# Plot this as a function of $\frac{\sigma(c_z)}{c_z}$ to see where it crosses $x$. (Points part the turnover at high $\frac{\sigma(c_z)}{c_z}$ cannot be trusted due to matrix inversion difficulties.

# %%
plt.figure()
plt.loglog(pa.fudge_frac_level, frac_err_sys, 'k', linewidth=3)
plt.hold(True)
plt.axhline(x, color='g', linestyle='--', linewidth=3)
plt.show()

# %% [markdown]
# For SDSS, the maximum level of $\frac{\sigma(c_z)}{c_z}$ allowed for systematic error from this source to make up at most 50\% of the integrated inverse signal to noise of the lensing signal is about 0.008.

# %%
StoNsq_sys = 56.255 
#Load  the statistical signal-to-noise * on gammaIA * (different from above)
StoNstat_sq = np.loadtxt('./txtfiles/StoN/StoNstat_Blazek_SDSS_deltaz=0.17_rlim=22.0_fixDls.txt')

ratio = np.sqrt(StoNstat_sq  / StoNsq_sys)
print "ratio=", ratio
